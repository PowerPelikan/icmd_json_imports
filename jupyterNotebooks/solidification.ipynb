# %%
import os 
import sys
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
from icmdoutput.models.user_scripts.scheil_plotting import Scheil

import plotly.express as px
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[1], line 4
#       2 import sys
#       3 sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), '..')))
# ----> 4 from icmdoutput.models.user_scripts import Scheil
#       6 import plotly.express as px
#       7 import pandas as pd
#
# ImportError: cannot import name 'Scheil' from 'icmdoutput.models.user_scripts' (unknown location)

# %%
sol = Solidification('../test/testfiles/teslaScheil.json', 'Solidification')
sol.get_temperatures()
# Out:
#      Temperature
# 0        520.044
# 1        522.314
# 2        524.352
# 3        526.389
# 4        528.426
# ..           ...
# 117      611.019
# 118      611.519
# 119      612.012
# 120      613.401
# 121      800.970
#
# [122 rows x 1 columns]

# %%
scheil = pd.concat([sol.set_new_temp_by_phase(), sol.get_percent_solidified_molar()], axis=1)
#scheil['Phase_key'] = scheil['Phase_region'].apply(lambda phase: "+".join(sorted(phase)))
scheil
# Out:
#      Temperature                                       Phase_region  \
# 0        520.044  AL2SI2SR+ALFEMNSI_ALPHA+ALFESI_BETA+C54_A2B+D0...
# 1        522.314  AL2SI2SR+ALFEMNSI_ALPHA+ALFESI_BETA+C54_A2B+D0...
# 2        524.352  AL2SI2SR+ALFEMNSI_ALPHA+ALFESI_BETA+C54_A2B+D0...
# 3        526.389  AL2SI2SR+ALFEMNSI_ALPHA+ALFESI_BETA+C54_A2B+D0...
# 4        528.426  AL2SI2SR+ALFEMNSI_ALPHA+ALFESI_BETA+C54_A2B+D0...
# ..           ...                                                ...
# 117      611.019                     C54_A2B+D022_A3B+FCC_A1+LIQUID
# 118      611.519                     C54_A2B+D022_A3B+FCC_A1+LIQUID
# 119      612.012                     C54_A2B+D022_A3B+FCC_A1+LIQUID
# 120      613.401                     C54_A2B+D022_A3B+FCC_A1+LIQUID
# 121      800.970                                             LIQUID
#
#      Percent solidified molar
# 0                        99.0
# 1                        98.9
# 2                        98.8
# ...

# %%
fig = px.line(scheil, x='Percent solidified molar', y='Temperature', color='Phase_region')
fig.show()
